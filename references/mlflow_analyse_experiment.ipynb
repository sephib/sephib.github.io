# %%
import pandas as pd
# import hvplot.pandas
import bokeh
import mlflow

# %%
mlflow.set_tracking_uri("sqlite:////rData/mlflow/tracking.db")
# mle = mlflow.get_experiment_by_name('cnn_pipe4')
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
mle = mlflow.search_runs(experiment_ids=[4])
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
mle.shape
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (43, 58)

# %%
# mle.head(2).dtypes
start_time = '2020-10-22 10:23:25'
end_time = '2020-10-22 11:06:19'
mask_time =(  mle['start_time']>=start_time) & (  mle['start_time']<=end_time)
runsid_242 = mle[mask_time]['run_id'].values.tolist()

# %%
# exp_runs = mle.sort_values(by=['start_time']).head(10)['run_id'].values.tolist()
mle.sort_values(by=['start_time'])  #['run_id'].values.tolist()
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                               run_id experiment_id    status  \
# 42  ef8e13c7617f4924aa8727c6dab00310             4  FINISHED
# 41  1c8a232d57a24c539f11512749c7abba             4  FINISHED
# 40  e8237bc410394712935cf4a4527d2412             4  FINISHED
# 39  a9eb68dccdbe421a988629ff4c9329e3             4  FINISHED
# 38  e9db8fcc8f954230b85013877612fd2c             4  FINISHED
# 37  1dbfc75e756640dc8421c6d91d1a6aa9             4  FINISHED
# 36  d2127afb21654040ad797b47724b5408             4  FINISHED
# 35  89321d98877c4c3e898c0a9df38bb567             4  FINISHED
# ...

# %%
metric_cols = [col for col in mle.columns if col.startswith('metrics') ]
params_cols = [col for col in mle.columns if col.startswith('params') ]

# %%
df_242 = mle[mle.run_id.isin(runsid_242)]

# %%
metric_cols + ['tags.mlflow.runName']
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['metrics.loss',
#  'metrics.val_loss',
#  'metrics.val_accuracy',
#  'metrics.training_score',
#  'metrics.stopped_epoch',
#  'metrics.restored_epoch',
#  'metrics.accuracy',
#  'metrics.f1-score',
#  'metrics.support',
#  'metrics.precision',
#  'metrics.recall',
#  'tags.estimator_name',
#  'tags.mlflow.runName']

# %%
dfg242 = df_242[metric_cols + ['tags.mlflow.runName']].groupby('tags.estimator_name').agg(['mean','std','min','max'])
dfg123 = df_123[metric_cols + ['tags.mlflow.runName']].groupby('tags.estimator_name').agg(['mean','std','min','max'])
dfg1974 = df_1974[metric_cols + ['tags.mlflow.runName']].groupby('tags.estimator_name').agg(['mean','std','min','max'])
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_compare = pd.concat([dfg1974.T.rename(columns={'Pipeline':'seed1974'}),
                       dfg123.T.rename(columns={'Pipeline':'seed123'}),
                        dfg242.T.rename(columns={'Pipeline':'seed242_20rounds'}),
                       ],
                       axis=1
                      )
df_compare
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tags.estimator_name           seed1974    seed123  seed242_20rounds
# metrics.loss           mean   0.598953   0.517262          0.789778
#                        std    0.217747   0.172916          0.224872
#                        min    0.260982   0.285525          0.398104
#                        max    1.036286   0.699249          1.066992
# metrics.val_loss       mean   0.344004   0.430646          0.436043
#                        std    0.136567   0.253497          0.107120
#                        min    0.190259   0.147193          0.193787
# ...

# %%
df_compare
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tags.estimator_name           seed1974    seed123  seed242_20rounds
# metrics.loss           mean   0.598953   0.517262          0.789778
#                        std    0.217747   0.172916          0.224872
#                        min    0.260982   0.285525          0.398104
#                        max    1.036286   0.699249          1.066992
# metrics.val_loss       mean   0.344004   0.430646          0.436043
#                        std    0.136567   0.253497          0.107120
#                        min    0.190259   0.147193          0.193787
# ...

# %%
df_compare.T#.plot(kind='bar', subplots=True);
# Out:
#                     metrics.loss                                \
#                             mean       std       min       max
# tags.estimator_name
# seed1974                0.598953  0.217747  0.260982  1.036286
# seed123                 0.517262  0.172916  0.285525  0.699249
# seed242_20rounds        0.789778  0.224872  0.398104  1.066992
#
#                     metrics.val_loss                                \
#                                 mean       std       min       max
# tags.estimator_name
# seed1974                    0.344004  0.136567  0.190259  0.599696
# seed123                     0.430646  0.253497  0.147193  0.743335
# seed242_20rounds            0.436043  0.107120  0.193787  0.603613
#
#                     metrics.val_accuracy            ... metrics.support        \
#                                     mean       std  ...             min   max
# tags.estimator_name                                 ...
# ...

# %%
_df = df_compare.reset_index()
# _df = pipe(assign('metric'))
_df= _df.assign(metric = _df['level_0']+'_' +_df['level_1']).drop(columns=['level_0','level_1']).set_index('metric')
_df
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tags.estimator_name           seed1974    seed123  seed242_20rounds
# metric
# metrics.loss_mean             0.598953   0.517262          0.789778
# metrics.loss_std              0.217747   0.172916          0.224872
# metrics.loss_min              0.260982   0.285525          0.398104
# metrics.loss_max              1.036286   0.699249          1.066992
# metrics.val_loss_mean         0.344004   0.430646          0.436043
# metrics.val_loss_std          0.136567   0.253497          0.107120
# metrics.val_loss_min          0.190259   0.147193          0.193787
# ...

# %%
runs = mle.search_runs()
runs.head(2)
# runs = runs[runs.experiment_id==0]
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-644908f0230c> in <module>
# ----> 1 runs = mle.search_runs()
#       2 runs.head(2)
#       3 # runs = runs[runs.experiment_id==0]
#
# AttributeError: 'NoneType' object has no attribute 'search_runs'

# %%
runs = mlflow.search_runs("4")
# Out:
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-bc9d2b25a6b1> in <module>
# ----> 1 runs = mlflow.search_runs(4)
#
# /opt/anaconda3/envs/vtreat/lib/python3.7/site-packages/mlflow/tracking/fluent.py in search_runs(experiment_ids, filter_string, run_view_type, max_results, order_by)
#     832         )
#     833
# --> 834     runs = _paginate(pagination_wrapper_func, NUM_RUNS_PER_PAGE_PANDAS, max_results)
#     835
#     836     info = {
#
# ...

# %%
runs
# Out:
# Empty DataFrame
# Columns: [run_id, experiment_id, status, artifact_uri, start_time, end_time]
# Index: []
